# %%
import funcoes
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature.texture import greycomatrix

# %%
##### Carregar as imagens
image1 = cv2.imread("Imagem_1_fatiada.jpg")
image2 = cv2.imread("Imagem_2_fatiada.jpg")
#image1_filtro_2D = funcoes.filtro_2D(image1)
glcm_imagem01 = greycomatrix(image1[0:128,0:128,0], [1], [0, np.pi/2], levels=256)
#glcm_imagem02 = greycomatrix(image2[0:128,0:128,0], [1], [0, np.pi/2], levels=256)
#funcoes.mostrar_imagem(image1)
#funcoes.dados_imagem(image1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-01bff569eefb> in <module>
#       3 image2 = cv2.imread("Imagem_2_fatiada.jpg")
#       4 #image1_filtro_2D = funcoes.filtro_2D(image1)
# ----> 5 glcm_imagem01 = greycomatrix(image1[0:128,0:128,0], [1], [0, np.pi/2], levels=256)
#       6 #glcm_imagem02 = greycomatrix(image2[0:128,0:128,0], [1], [0, np.pi/2], levels=256)
#       7 #funcoes.mostrar_imagem(image1)
#
# NameError: name 'np' is not defined

# %%
funcoes.LDA_class(image1)
# Out:
# /usr/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
funcoes.LDA_class(image2)
# Out:
# /usr/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /usr/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:402: RuntimeWarning: invalid value encountered in true_divide
#   S**2))[:self._max_components]

# %%
a = image1[0:128,0:128,0]
x = [i for i in range(129)]
y = [i for i in range(129)]
plt.scatter(a)
# Out:
# [<matplotlib.lines.Line2D at 0x7f6bac4b1650>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b1890>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b1a50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b1c10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b1dd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b1f90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b8210>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b83d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b1d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b1fd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac50b750>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b8a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b8bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b8d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4b8f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bc150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bc310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bc4d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bc690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bc850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bca10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bcbd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bcd90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4bcf50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c04d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c0f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c44d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c4f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c84d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4c8f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cd150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cd310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cd4d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cd690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cd850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cda10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cdbd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cdd90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4cdf50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d04d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d0f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d44d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d4f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d84d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4d8f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4dd150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4dd310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4dd4d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4dd690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4dd850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4dda10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ddbd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ddd90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ddf50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e24d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e2f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e64d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6a10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6bd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6d90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4e6f50>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ea150>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ea310>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ea4d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ea690>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ea850>,
#  <matplotlib.lines.Line2D at 0x7f6bac4eaa10>,
#  <matplotlib.lines.Line2D at 0x7f6bac4eabd0>,
#  <matplotlib.lines.Line2D at 0x7f6bac4ead90>,
#  <matplotlib.lines.Line2D at 0x7f6bac4eaf50>,
#  <matplotlib.lines.Line2D at 0x7f6bac46d150>,
#  <matplotlib.lines.Line2D at 0x7f6bac46d310>,
#  <matplotlib.lines.Line2D at 0x7f6bac46d4d0>,
#  <matplotlib.lines.Line2D at 0x7f6bac46d690>,
#  <matplotlib.lines.Line2D at 0x7f6bac46d850>]

# %%
# Out:
#   File "<ipython-input-17-df9b4340d567>", line 1
#     print(for i in range(129): i)
#             ^
# SyntaxError: invalid syntax
